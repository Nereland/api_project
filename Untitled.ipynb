# %%
import PIL
from PIL import Image, ImageFilter

# %%
im = Image.open("images/akira.png")
im.size
# Out:
# (540, 344)

# %%
im.resize((200,156))
# Out:
# <PIL.Image.Image image mode=RGBA size=200x156 at 0x7F9E5960B0A0>

# %%
im.save("images/akirare.png")

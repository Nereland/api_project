# %%
import pandas as pd
df = pd.read_csv("inputs/scriptlk.csv", sep = ",", engine = "python" )
df.head(60)
# Out:
#       user                                            message  rooms
# 0   Rafiki  We would like to take a few moments to get you...      1
# 1     Scar  Why! If it isn't my big brother descending fro...      1
# 2   Mufasa  Sarabi and I didn't see you at the presentatio...      1
# 3     Scar           That was today? Oh, I feel simply awful.      1
# 4     Scar                         Must have slipped my mind.      1
# 5     Zazu  Yes, well, as slippery as your mind is, as the...      1
# 6     Scar  Well, I was first in line... until the little ...      1
# 7   Mufasa   That “hairball” is my son -and your future king.      1
# 8     Scar                   Ohh, I shall practice my curtsy.      1
# 9   Mufasa                  Don't turn your back on me, Scar.      1
# 10    Scar  On, no, Mufasa. Perhaps you shouldn't turn you...      1
# 11  Mufasa                               Is that a challenge?      1
# 12    Scar  Temper, temper. I wouldn't dream of challengin...      1
# ...

# %%
df.columns
# Out:
# Index(['user', 'message', 'rooms'], dtype='object')
